# %% [markdown]
# # Relatório de Análise V

# %% [markdown]
# ## Tratamento de Dados Faltantes

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados
# Out:
#               Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento        Centro        1      0       0    15   800.0
# 1      Apartamento  Higienópolis        1      0       0    48   800.0
# 2      Apartamento  Higienópolis        1      0       0    48   800.0
# 3      Apartamento      Cachambi        2      0       0    50  1300.0
# 4      Apartamento        Grajaú        2      1       0    70  1500.0
# ...            ...           ...      ...    ...     ...   ...     ...
# 19835    Quitinete        Glória        1      0       0    10   400.0
# 19836    Quitinete      Flamengo        1      0       0    23   900.0
# 19837    Quitinete        Centro        1      0       0    24  1100.0
# 19838    Quitinete    Copacabana        1      0       0    22  1500.0
# 19839    Quitinete        Centro        0      0       0    27   800.0
#
#        Condominio   IPTU  Valor m2 Tipo Agregado
# 0           390.0   20.0     53.33   Apartamento
# 1           230.0    0.0     16.67   Apartamento
# 2           230.0    0.0       NaN   Apartamento
# 3           301.0   17.0     26.00   Apartamento
# 4           642.0   74.0     21.43   Apartamento
# ...           ...    ...       ...           ...
# 19835       107.0   10.0     40.00   Apartamento
# 19836       605.0    0.0     39.13   Apartamento
# 19837       323.0    0.0     45.83   Apartamento
# 19838       286.0  200.0     68.18   Apartamento
# 19839         NaN   25.0     29.63   Apartamento
#
# [19840 rows x 11 columns]

# %%
dados.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU  \
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False       False  False
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False  False
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 19835  False   False    False  False   False  False  False       False  False
# 19836  False   False    False  False   False  False  False       False  False
# 19837  False   False    False  False   False  False  False       False  False
# 19838  False   False    False  False   False  False  False       False  False
# 19839  False   False    False  False   False  False  False        True  False
#
#        Valor m2  Tipo Agregado
# 0         False          False
# 1         False          False
# 2          True          False
# 3         False          False
# 4         False          False
# ...         ...            ...
# 19835     False          False
# 19836     False          False
# 19837     False          False
# 19838     False          False
# 19839     False          False
#
# [19840 rows x 11 columns]

# %%
dados.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio  IPTU  \
# 0      True    True     True   True    True  True   True        True  True
# 1      True    True     True   True    True  True   True        True  True
# 2      True    True     True   True    True  True   True        True  True
# 3      True    True     True   True    True  True   True        True  True
# 4      True    True     True   True    True  True   True        True  True
# ...     ...     ...      ...    ...     ...   ...    ...         ...   ...
# 19835  True    True     True   True    True  True   True        True  True
# 19836  True    True     True   True    True  True   True        True  True
# 19837  True    True     True   True    True  True   True        True  True
# 19838  True    True     True   True    True  True   True        True  True
# 19839  True    True     True   True    True  True   True       False  True
#
#        Valor m2  Tipo Agregado
# 0          True           True
# 1          True           True
# 2         False           True
# 3          True           True
# 4          True           True
# ...         ...            ...
# 19835      True           True
# 19836      True           True
# 19837      True           True
# 19838      True           True
# 19839      True           True
#
# [19840 rows x 11 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19840 entries, 0 to 19839
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           19839 non-null  object
#  1   Bairro         19840 non-null  object
#  2   Quartos        19840 non-null  int64
#  3   Vagas          19840 non-null  int64
#  4   Suites         19840 non-null  int64
#  5   Area           19840 non-null  int64
#  6   Valor          19840 non-null  float64
#  7   Condominio     19837 non-null  float64
#  8   IPTU           19835 non-null  float64
#  9   Valor m2       19838 non-null  float64
#  10  Tipo Agregado  19840 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 1.7+ MB

# %%
dados[dados['Valor m2'].isnull()]
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 2  Apartamento             Higienópolis        1      0       0    48  800.0
# 8  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54  950.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 2       230.0   0.0       NaN   Apartamento
# 8       300.0  28.0       NaN   Apartamento

# %%
A = dados.shape[0]
dados.dropna(subset = ['Valor m2'], inplace =  True)

B = dados.shape[0]
A - B
# Out:
# 2

# %%
dados[dados['Valor m2'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU, Valor m2, Tipo Agregado]
# Index: []

# %% [markdown]
# ## Tratamento de Dados Faltantes (continuação)

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 3

# %%
selecao = (dados['Tipo'] == 'Apartamento') & (dados['Condominio'].isnull())

# %%
A = dados.shape[0]
dados = dados[~selecao]

B = dados.shape[0]
A - B
# Out:
# 1

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 2

# %%
dados = dados.fillna({'Condominio' : 0, 'IPTU' : 0})

# %%
dados
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 3      Apartamento             Cachambi        2      0       0    50  1300.0
# 4      Apartamento               Grajaú        2      1       0    70  1500.0
# 5      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19835    Quitinete               Glória        1      0       0    10   400.0
# 19836    Quitinete             Flamengo        1      0       0    23   900.0
# 19837    Quitinete               Centro        1      0       0    24  1100.0
# 19838    Quitinete           Copacabana        1      0       0    22  1500.0
# 19839    Quitinete               Centro        0      0       0    27   800.0
#
#        Condominio   IPTU  Valor m2 Tipo Agregado
# 0           390.0   20.0     53.33   Apartamento
# 1           230.0    0.0     16.67   Apartamento
# 3           301.0   17.0     26.00   Apartamento
# 4           642.0   74.0     21.43   Apartamento
# 5           455.0   14.0     16.67   Apartamento
# ...           ...    ...       ...           ...
# 19835       107.0   10.0     40.00   Apartamento
# 19836       605.0    0.0     39.13   Apartamento
# 19837       323.0    0.0     45.83   Apartamento
# 19838       286.0  200.0     68.18   Apartamento
# 19839         0.0   25.0     29.63   Apartamento
#
# [19837 rows x 11 columns]

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 0

# %%
dados[dados['IPTU'].isnull()].shape[0]
# Out:
# 0

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19837 entries, 0 to 19839
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           19836 non-null  object
#  1   Bairro         19837 non-null  object
#  2   Quartos        19837 non-null  int64
#  3   Vagas          19837 non-null  int64
#  4   Suites         19837 non-null  int64
#  5   Area           19837 non-null  int64
#  6   Valor          19837 non-null  float64
#  7   Condominio     19837 non-null  float64
#  8   IPTU           19837 non-null  float64
#  9   Valor m2       19837 non-null  float64
#  10  Tipo Agregado  19837 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 1.8+ MB

# %%
dados.to_csv('dados/aluguel_residencial.csv', sep = ';', index = False)
