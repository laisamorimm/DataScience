# %% [markdown]
# # Aula 1

# %% [markdown]
# ## Vídeo 1.2

# %%
import pandas as pd

# %%
carbonico = pd.read_csv('co2.csv',sep='\t')

# %%
carbonico.head()
# Out:
#        data   media
# 0  1980.042  338.45
# 1  1980.125  339.15
# 2  1980.208  339.48
# 3  1980.292  339.87
# 4  1980.375  340.30

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(carbonico['data'],carbonico['media'])
plt.ylabel('CO2')
plt.xlabel('Data')

# MODELO DE TENDÊNCIA -> que parece uma reta subindo ou descendo e uma parabola
# MODELO SACIONAL -> onde tem um crescimento e um descrecimento continui (sempre caindo e subindo de forma muito parecida porem sempre subindo ou descendo)
# Out:
# Text(0.5, 0, 'Data')

# %%
nasc = pd.read_csv('nascimentos.csv')

# %%
nasc.head()
# Out:
#          data  n_nasc
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
plt.plot(nasc["data"],nasc['n_nasc'])
plt.ylabel("Número de nascimentos")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
# para botar a data em baixo
nasc["data"] = pd.to_datetime(nasc["data"])

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
plt.figure(figsize = (20,4));
plt.plot(nasc["data"],nasc['n_nasc'])
plt.ylabel("Número de nascimentos")
plt.xlabel("Data")

# MODELO DE MEDIA ZERO -> varia em torno da média 
# MODELO DE PASSEIO ALEATÓRIO -> (soma acumulativa do modelo de media zero)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ## Vídeo 1.3

# %%
import numpy as np

# %%
media_carb = np.mean(carbonico["media"])

# %%
dt_carb = carbonico["data"][1] - carbonico["data"][0]

# %%
plt.plot(carbonico["data"],carbonico['media'])
plt.plot(carbonico.iloc[-1,0] + dt_carb,media_carb, '*')
plt.ylabel("CO2")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
media_nasc = np.mean(nasc["n_nasc"])

# %%
dt_nasc = nasc["data"][1]-nasc["data"][0]

# %%
plt.plot(nasc["data"],nasc["n_nasc"])
plt.plot(nasc.iloc[-1,0]+dt_nasc,media_nasc, '*')
plt.ylabel("Número de nascimentos")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
carbonico.shape
# Out:
# (477, 2)

# %%
media_tres_pontos_c = np.mean(carbonico["media"][474:476])

# %%
plt.plot(carbonico["data"],carbonico['media'])
plt.plot(carbonico.iloc[-1,0]+dt_carb,media_tres_pontos_c, '*')
plt.ylabel("CO2")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
nasc.shape
# Out:
# (365, 2)

# %%
media_tres_pontos_n = np.mean(nasc["n_nasc"][362:364])

# %%
plt.plot(nasc["data"],nasc["n_nasc"])
plt.plot(nasc.iloc[-1,0]+dt_nasc,media_tres_pontos_n, '*')
plt.ylabel("Número de nascimentos")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
import numpy as np

# %%
media_carb = np.mean(carbonico['media'])

# %%
dt_carb = carbonico['data'][1] - carbonico['data'][0]

# %%
plt.plot(carbonico['data'], carbonico['media'])
plt.plot(carbonico.iloc[-1,0] + dt_carb, media_carb, '*')
plt.ylabel('media')
plt.xlabel('data')
# Out:
# Text(0.5, 0, 'data')

# %%
media_nasc = np.mean(nasc['n_nasc'])

# %%
dt_nasc = nasc['data'][1] - nasc['data'][0]

# %%
plt.plot(nasc['data'], nasc['n_nasc'])
plt.plot(nasc.iloc[-1,0] + dt_nasc, media_nasc, '*')
plt.ylabel('media')
plt.xlabel('data')
# Out:
# Text(0.5, 0, 'data')

# %%
carbonico.shape
# Out:
# (477, 2)

# %%
media_tres_pontos_c = np.mean(carbonico['media'][474:476])

# %%
plt.plot(carbonico['data'], carbonico['media'])
plt.plot(carbonico.iloc[-1,0] + dt_carb, media_tres_pontos_c, '*')
plt.ylabel('media')
plt.xlabel('data')
# Out:
# Text(0.5, 0, 'data')

# %%
nasc.shape
# Out:
# (365, 2)

# %%
media_tres_pontos_n = np.mean(nasc['n_nasc'][362:364])

# %%
plt.plot(nasc['data'], nasc['n_nasc'])
plt.plot(nasc.iloc[-1,0] + dt_nasc, media_tres_pontos_n, '*')
plt.ylabel('media')
plt.xlabel('data')
# Out:
# Text(0.5, 0, 'data')

# %%
#rolar de 5 em 5 e calculando a media
media_movel_c = carbonico.rolling(5).mean()

# %%
plt.plot(carbonico['data'], carbonico['media'])
plt.plot(carbonico['data'], media_movel_c['media'])

# %%
media_movel_n = nasc.rolling(5).mean()

# %%
plt.plot(nasc['data'], nasc['n_nasc'])
plt.plot(nasc['data'], media_movel_n['n_nasc'])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result_c = seasonal_decompose(carbonico.set_index('data'), period = 35)

# %%
result_c.plot();
# primeiro real
# e o data decomposto nas outras linhas

# %%
result_n = seasonal_decompose(nasc.set_index('data'), period = 35)

# %%
result_n.plot();

# %%
carbonico.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff6c8bfc190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff6c8c33820>]],
#       dtype=object)

# %%
carbonico['media'].hist()

# %%
divide = int(len(carbonico)/2)

# %%
x = carbonico['media'].values

# %%
c1, c2 = x[0:divide], x[divide:]

# %%
c1.mean()
# Out:
# 352.31550420168065

# %%
c2.mean()
# Out:
# 387.816359832636

# %%
c1.var()
# Out:
# 73.90219533401597

# %%
c2.var()
# Out:
# 151.542490933282

# %%
divide = int(len(nasc)/2)

# %%
x = nasc['n_nasc'].values

# %%
n1,n2 = x[0:divide], x[divide:]

# %%
n1.mean()
# Out:
# 39.76373626373626

# %%
n2.mean()
# Out:
# 44.185792349726775

# %%
n1.var()
# Out:
# 49.21341021615746

# %%
n2.var()
# Out:
# 48.708650601690096

# %%
# aparecentemente a base carbonico não é uma seria estacionaria, pois a diferença é muito grande
# aparecentemente a base de nascimento é uma seria estacionaria, pois a diferença é pouca

# %%
from statsmodels.tsa.stattools import adfuller

# %%
resultado_c = adfuller(carbonico['media'].values)

# %%
# quanto mais negativo mais temos a certeza que a serie é estacionaria
# quando tem tendencia não é estacionaria
print('Estatística ADF ', resultado_c[0])
# Out:
# Estatística ADF  3.036828829166984

# %%
# quando o valor do p-valor é menos que 0.05 considera a serie estacionaria e se for maior a serie não é estacionaria
print('p-valor %f' %resultado_c[1])
# Out:
# p-valor 1.000000

# %%
resultado_n = adfuller(nasc['n_nasc'].values)

# %%
print('Estatística ADF ', resultado_n[0])
# Out:
# Estatística ADF  -4.808291253559764

# %%
print('p-valor %f' %resultado_n[1])
# Out:
# p-valor 0.000052

# %%
carbonico = carbonico.set_index('data')

# %%
carbonico
# Out:
#            media
# data
# 1980.042  338.45
# 1980.125  339.15
# 1980.208  339.48
# 1980.292  339.87
# 1980.375  340.30
# ...          ...
# 2019.375  411.16
# 2019.458  410.35
# 2019.542  408.69
# 2019.625  407.43
# 2019.708  407.65
#
# [477 rows x 1 columns]

# %%
carbonico_treino = carbonico[1980.042:2015]

# %%
carbonico_teste = carbonico[2015:]

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
modelo_ajustado = SimpleExpSmoothing(carbonico_treino).fit(smoothing_level = 0.5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:213: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
carbonico_teste.shape
# Out:
# (57, 1)

# %%
modelo_previsto = modelo_ajustado.forecast(57)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
# dados suavizados
plt.plot(carbonico_treino)
plt.plot(carbonico_treino.index, modelo_ajustado.fittedvalues.values)
plt.plot(carbonico_teste, 'g')
plt.plot(carbonico_teste.index, modelo_previsto, 'r.')

# %%
nasc = nasc.set_index('data')

# %%
nasc_treino = nasc['1959-01-01':'1959-12-01']

# %%
nasc_teste = nasc['1959-12-01':]

# %%
modelo_ajustado = SimpleExpSmoothing(nasc_treino).fit(smoothing_level = 0.5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
nasc_teste.shape[0]
# Out:
# 31

# %%
modelo_previsto = modelo_ajustado.forecast(31)

# %%
plt.plot(nasc_treino)
plt.plot(nasc_treino.index,modelo_ajustado.fittedvalues.values)
plt.plot(nasc_teste, 'g')
plt.plot(nasc_teste.index, modelo_previsto, 'r.')

# %% [markdown]
# ## Holt - Winters

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
modelo_ajustado = ExponentialSmoothing(carbonico_treino.values, trend = 'additive', seasonal = 'additive', seasonal_periods = 35).fit()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters.py:743: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warn("Optimization failed to converge. Check mle_retvals.",

# %%
carbonico.shape
# Out:
# (477, 1)

# %%
carbonico_teste.shape
# Out:
# (57, 1)

# %%
modelo_previsto = modelo_ajustado.predict(start = 420, end = 476)

# %%
plt.figure(figsize = (10,4))
plt.plot(carbonico_treino)
plt.plot(carbonico_teste, 'g')
plt.plot(carbonico_teste.index, modelo_previsto, 'r.')

# %%
modelo_ajustado = ExponentialSmoothing(nasc_treino.values, trend = 'multiplicative', seasonal = None).fit()

# %%
nasc_treino.shape
# Out:
# (335, 1)

# %%
nasc_teste.shape
# Out:
# (31, 1)

# %%
modelo_previsto_suave = modelo_ajustado.predict(start =335, end = 365)

# %%
plt.plot(nasc_treino)
plt.plot(nasc_test, 'g')
plt.plot(nasc_teste.index, modelo_previsto_suave, 'r')
# não previa a sozonalidade

# %% [markdown]
# ## Corelação

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
# os valores mais altos de corelação, indicam que extiste partes semelhantes na serie temporal por diversos atrasos
plot_acf(carbonico);

# %% [markdown]
# ## Altocorrelação

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(carbonico, lags = 20);
# dois valores altos por conta da sozanalidade e depois com a remoção todos os outros valore vão 
# para baixo ficando na faixa azul

# %%
plot_acf(nasc['n_nasc'], lags = 20);
# alta correlação total, e como não se tem periodicidade nos dados, os valores caem rapidamente

# %%
plot_pacf(nasc['n_nasc'], lags = 20)
# correlação parcial

# %%
from statsmodels.tsa.ar_model import AutoReg

# %%
lista = np.linspace(1,40,40)

# %%
modelo_ajustado = AutoReg(carbonico_treino.values, lags = lista, trend = 'c', seasonal = True, period = 35).fit()

# %%
modelo_previsto = modelo_ajustado.predict(start = 420, end = 476)

# %%
plt.plot(carbonico_treino)
plt.plot(carbonico_teste, 'g')
plt.plot(carbonico_teste.index, modelo_previsto, 'r.')

# %%
modelo_ajustado = AutoReg(nasc_treino.values, lags = lista, trend = 'c', seasonal = True, period = 35).fit()

# %%
modelo_previsto_ar = modelo_ajustado.predict(start = 335, end = 365)

# %%
plt.figure(figsize = (10,4))
plt.plot(nasc_treino)
plt.plot(nasc_teste, 'g')
plt.plot(nasc_teste.index, modelo_previsto_ar, 'r')

# %%
plt.plot(nasc_teste, 'g', label = 'valor_real')
plt.plot(nasc_test.index, modelo_previsto_suave, 'b-', label = 'previsão HotWinters')
plt.plot(nasc_test.index, modelo_previsto_ar, 'r', label = 'previsão autoregressão')
plt.legend()

# %%
# ver qual é o melhor, porem olhando por numeros
Erro_prev_s = nasc_teste['n_nasc'] - modelo_previsto_suave

# %%
Erro_prev = nasc_teste['n_nasc'] - modelo_previsto_ar

# %%
plt.plot(Erro_prev_s, 'g')
plt.plot(Erro_prev, 'r')

# %%
np.mean(Erro_prev_s)
# Out:
# -3.53612052204375

# %%
np.mean(Erro_prev)
# Out:
# -1.608308080450107

# %%
# mais proximo possivel de zero, o melhor é o Erro_prev

# %%
np.mean(np.abs(Erro_prev_s))
# Out:
# 6.374535655610508

# %%
np.mean(np.abs(Erro_prev))
# Out:
# 5.496720548092111

# %%
# mesmo prosedimento
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(nasc_test['n_nasc'], modelo_previsto_ar)

# %%
mae
# Out:
# 5.496720548092111

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(nasc_teste['n_nasc'], modelo_previsto_suave)
# Out:
# 54.3958273181745

# %%
mean_squared_error(nasc_teste['n_nasc'], modelo_previsto_ar)
# Out:
# 45.43739422181352
